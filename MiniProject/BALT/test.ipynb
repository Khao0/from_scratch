# %%
# !pip3 install pygame
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 5.0 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !pip3 install pygame_gui
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.9/30.9 MB 4.6 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 2.0 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !python3 --version
# Out:
# Python 3.10.9

# %% [markdown]
# ## Load

# %%
results = []
for i, file_name in enumerate(["boy_mat_score", "boy_bone_age", "girl_mat_score", "girl_bone_age",]):
    
    with open(f"{file_name}.txt", "r") as fread:
        lines = fread.readlines()
        results.append([float(line.strip()) for line in lines])

# %%
results[2]
# Out:
# [126.0,
#  130.0,
#  134.0,
#  139.0,
#  143.0,
#  148.0,
#  153.0,
#  158.0,
#  163.0,
#  168.0,
#  174.0,
#  178.0,
#  182.0,
#  186.0,
#  191.0,
#  195.0,
#  200.0,
#  204.0,
#  209.0,
#  214.0,
#  219.0,
#  222.0,
#  225.0,
#  228.0,
#  231.0,
#  234.0,
#  238.0,
#  241.0,
#  244.0,
#  248.0,
#  251.0,
#  255.0,
#  258.0,
#  262.0,
#  265.0,
#  269.0,
#  273.0,
#  277.0,
#  281.0,
#  284.0,
#  288.0,
#  292.0,
#  296.0,
#  301.0,
#  305.0,
#  309.0,
#  313.0,
#  318.0,
#  322.0,
#  327.0,
#  331.0,
#  335.0,
#  339.0,
#  343.0,
#  347.0,
#  351.0,
#  355.0,
#  359.0,
#  363.0,
#  367.0,
#  372.0,
#  377.0,
#  382.0,
#  387.0,
#  393.0,
#  398.0,
#  404.0,
#  409.0,
#  415.0,
#  421.0,
#  427.0,
#  434.0,
#  441.0,
#  448.0,
#  455.0,
#  462.0,
#  470.0,
#  478.0,
#  485.0,
#  493.0,
#  501.0,
#  509.0,
#  518.0,
#  526.0,
#  535.0,
#  543.0,
#  552.0,
#  561.0,
#  570.0,
#  579.0,
#  589.0,
#  597.0,
#  605.0,
#  614.0,
#  622.0,
#  631.0,
#  640.0,
#  649.0,
#  658.0,
#  667.0,
# ...

# %%
# Out:
# <method-wrapper '__bool__' of NoneType object at 0x1046eff38>
